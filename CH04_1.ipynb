# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH04_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/IPC/Images/lena.jpg')
img = cv2.imread('/content/gdrive/My Drive/IPC/Images/cell.bmp')
RGB_img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
R_img1,G_img1,B_img1 = cv2.split(RGB_img1)
plt.figure(figsize=(10,10))
plt.subplot(111), plt.imshow(RGB_img1)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(359.5), np.float64(359.5), np.float64(-0.5))

# %%
hist = cv2.calcHist([R_img1],[0],None,[256],[0,255])
plt.subplot(112),plt.plot(hist,color ='r')
plt.xlim([0, 256])
hist = cv2.calcHist([G_img1], [0], None, [256], [0,255])
plt.plot(hist,color ='g')
plt.xlim([0, 255])
hist = cv2.calcHist([B_img1], [0], None, [256], [0,255])
plt.plot(hist,color ='b')
plt.xlim([0, 255])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3801621782.py in <cell line: 0>()
#       1 hist = cv2.calcHist([R_img1],[0],None,[256],[0,255])
# ----> 2 plt.subplot(112),plt.plot(hist,color ='r')
#       3 plt.xlim([0, 256])
#       4 hist = cv2.calcHist([G_img1], [0], None, [256], [0,255])
#       5 plt.plot(hist,color ='g')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     587         else:
#     588             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# ...

# %%
gBin = np.zeros((gimg1.shape[0], gimg1.shpae[1], dtype= np.unbyte))

# %%
''''Threshold = 180
for h in range(gimg1.shape[0])
  for w in range(gimg1.shpae[1])
   if gimg1
    (np.int32(RGB_img1[h, w][0]))
   gBin[h, w]

cv2_imshow(gBin)''''

# %%
T1 = 128
T2 = 0
T0 = 1

# %%
def threshold_update(img,bimg, h, w, T1)
  sum1 = 0
  count1 = 1
  sum2 = 0
  count2 = 1

  for h in range(gimg1.shape[0]):
    for w in range(gimg1.shpap[1]):
      if(bimg[h, w]== 0):
        sum1 = np.int32(sum1 + img[h, w])
        count1 += 1
      else:
        sum2 = np.int32(sum2 + img[h, w])
        count2 += 1
      avg1 = sum1/count1
      avg2 = sum2/count2
      T = (avg1 +abg2)/2
      return T
# Out:
#   File "/tmp/ipython-input-529155582.py", line 1
#     def threshold_update(img,bimg, h, w, T1)
#                                             ^
# SyntaxError: expected ':'

# %%
for h in range(img.shape[0]):
    for w in range(img.shpap[1]):
      if img[h, w] > T1:
        gBin[h, w] = 0
      else:
        gBin[h, w] = 255

# %%
while True:
  T1 = threshold_update(gimg1, gBin)
  print(T2)

  if(np.abs(T1 - T2) < T0):
    break
  else:
    T1 = T2
    for h in range(gimg1.shpae[0]):
      for w in range(gimg1.shape[1]):
        if gimg1[h,w] > T1:
          gBin[h, w] = 0
        else:
          gBin[h, w] = 255

print(T2)
cv2_imshow(dBin)
