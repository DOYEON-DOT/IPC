# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/CH1/pby.jpg')

# %%
print(img.shape)
# Out:
# (1800, 1200, 3)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
import os

image_path = '/content/gdrive/My Drive/IP/CH1/pby.jpg'

if os.path.exists(image_path):
    print(f"Image found at: {image_path}")
else:
    print(f"Image not found at: {image_path}")
# Out:
# Image not found at: /content/gdrive/My Drive/IP/CH1/pby.jpg
