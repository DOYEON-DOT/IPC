# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH05_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPC/Images/lena.jpg')
RGB_img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
def saturation(value):
  if(value > 256):
    value = 255
  elif(value < 0):
    value = 0
  return value

# %%
kernel3 = np.ones((3,3),np.float32)/9

# %%
output = cv2.filter2D(gimg,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
g0ut = np.zeros(gimg.shape[0], gimg.shape[1], dtype = np.ubyte)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2442750142.py in <cell line: 0>()
# ----> 1 g0ut = np.zeros(gimg.shape[0], gimg.shape[1], dtype = np.ubyte)
#
# TypeError: argument for zeros() given by name ('dtype') and position (position 1)

# %%
for i in range(1, gimg.shape[0]-1):
  for w in range(1, gimg.shape[1]-1)
    sum = 0
    for i in range(-1, 2):
      for j in range(-1, 2):
        sum += gimg[h+i, w+j] * kernel3[i +1, j+1]
      sum = saturation(sum)
      g0ut[h, w] = sum

cv2_imshow(g0ut)

# %%
output = cv2.filter2D(output,-1,kernel3)
cv2_imshow(output)
