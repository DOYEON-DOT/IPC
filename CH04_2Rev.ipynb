# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH04_2Rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/IPC/Images/cell.bmp')
RGB_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
output_img = np.zeros((RGB_img.shape[0], RGB_img.shape[1]))

# %%
for h in range(RGB_img.shape[0]):
  for w in range(RGB_img.shape[1]):
    if(RGB_img[h,w,0] < 140):
      output_img[h,w] = 255
    else:
      output_img[h,w] = 0

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.title("Image1")
plt.imshow(RGB_img)
plt.axis("off")
plt.subplot(1,2,2)
plt.title("Segmented Image")
plt.imshow(output_img, cmap='gray')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(359.5), np.float64(359.5), np.float64(-0.5))
