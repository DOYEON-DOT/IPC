# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPC/Images/gsy.jpg')
gray_img = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)

# %%
output_img = cv2.medianBlur(gray_img, 5)
cv2_imshow(output_img)
# Out:
# <PIL.Image.Image image mode=L size=630x945>

# %%
img = cv2.imread('/content/gdrive/My Drive/IPC/Images/lena.jpg')
gray_img = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)

# %%
mean_img = cv2.blur(gray_img, (5, 5))
edge_img = cv2.addWeighted(gray_img, 1.0 , mean_img, -1.0, 0)
output_img = cv2.addWeighted(gray_img, 1.0, edge_img, 3.0, 0)

# %%
plt.figure(figsize=(20, 20))
plt.subplot(1, 3, 1)
plt.title('Image1')
plt.imshow(output_img, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title('Edge Image')
plt.imshow(edge_img, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title('Unsharpe Image')
plt.imshow(output_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
edgeImage = cv2.addWeighted(gray_img, 1, outimg, -1, 0)
cv2_imshow(edgeImage)

# %%
unsharp_image = cv2.addWeighted(gray_img, 2, outImg, -1, 0)
cv2_imshow(unsharp_image)i

# %%
kernel3 = np.ones((3,3), np.float32)/9
kernel3 [0][0]  = -1/9
kernel3 [0][1] = -1/9
kernel3 [1][0]
