# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
img = cv2.imread('/content/gdrive/My Drive/IPC/Images/lena.jpg')
# Out:
# Mounted at /content/gdrive

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(RGB_img)

# %%
R_img, G_img, B_img = cv2.split(RGB_img)

# %%
print(R_img.shape)
# Out:
# (512, 512)

# %%
CImg = RGB_img

# %%
CImg[:,:,0] = R_img
CImg[:,:,1] = R_img
CImg[:,:,2] = R_img

# %%
CImg[:,:,0] = G_img
CImg[:,:,1] = G_img
CImg[:,:,2] = G_img

# %%
CImg[:,:,0] = B_img
CImg[:,:,1] = B_img
CImg[:,:,2] = B_img

# %%
plt.imshow(CImg)

# %%
HSV_img = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2HSV)

# %%
H_img, S_img, V_img = cv2.split(HSV_img)
CImg[:,:,0] = V_img
CImg[:,:,1] = V_img
CImg[:,:,2] = V_img
plt.imshow(CImg)
