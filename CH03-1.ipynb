# %%
from google.colab.patches import cv2_imshow

# %%
import numpy as np

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#영상 불러오기
img1 = cv2.imread('/content/gdrive/My Drive/IPC/Images/AERO2.bmp')
img2 = cv2.imread('/content/gdrive/My Drive/IPC/Images/milkdrop.bmp')

# %%
# BGR채널순서를 RGE채널로 변경
RGB_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
RGB_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
output_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-856568899.py in <cell line: 0>()
#       1 # BGR채널순서를 RGE채널로 변경
# ----> 2 RGB_img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
#       3 RGB_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
#       4 output_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# RGB 채널 나누기
R_img1, G_img1,B_img1=cv2.split(RGB_img1)
R_img2, G_img2,B_img2=cv2.split(RGB_img2)

# %%
# 출력 array 생성하고 0으로 초기화, unsigned byte (0~255)로 설정
R_plus = np.zeros((RGB_img1.shape[0], RGB_img.shpae[1]),dtype=np.unbyte)
G_plus = np.zeros((RGB_img1.shape[0], RGB_img.shpae[1]),dtype=np.unbyte)
B_plus = np.zeros((RGB_img1.shape[0], RGB_img.shpae[1]),dtype=np.unbyte)

# %%
#for문을 돌며 픽셀 더하기 계산하기
for h in range(RGB_img1.shape[0]): #영상의 높이
  for w in range(RGB_img1.shape[1]): #영상의 너비
    r + np.int32(R_img[h,w])+np.int32(R_img2[h,w]) #타입 변환하기
    if(r >255):
      R_plus[h,w] = 255 # Saturation
    else:
      R_plus[h,w] = r
    g = np.int32(G_img[h, w])+np.int32(G_img2[h,w]) #타입 변환하기
    if(g> 255):
      G_plus[h,w] =255 #Saturation
    else:
      G_plus[h,w] = g
    b = np.int32(B_img[h, w])+np.int32(B_img2[h,w]) #타입 변환하기
    if(b >255):
      B_plus[h,w] = 255 # Saturation

# %%
#그림을 화면에 출력
plt.figure(figsize= 20,20) # 영상의 크기를 키워주기
plt.subplot(1,3,1) # 1행 3열에서 1번째 열
plt.title("Image1")
plt.imshow(RGB_img1)
plt.axis("off")
plt.subplot(1,3,2) #1행 3열에서 2번째 열
plt.title("Image2")
plt.imshow(RGB_img2)
plt.axis("off")
plt.subplot(1, 3, 3) #1행 3열에서 3번째 열
output_img[:,:,0]=R_plus
output_img[:,:,1]=G_plus
output_img[:,:,2]=B_plus
plt.title("Addded image")
plt.imshow(output_img)
plt.axis("off")
plt.show()
