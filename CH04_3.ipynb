# %% [markdown]
# <a href="https://colab.research.google.com/github/DOYEON-DOT/IPC/blob/main/CH04_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img1 = cv2.imread('/content/gdrive/My Drive/IPC/Images/girl.jpg')
Img1 = cv2.imread('/content/gdrive/My Drive/IPC/Images/pentagon.bmp')
RGB_img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
output_img = np.zeros((RGB_img1.shape[0], RGB_img1.shape[1]))

# %%
R_img1,G_img1,B_img1 = cv2.split(RGB_img1)
plt.subplot(111), plt.imshow(RGB_img1)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
hist = cv2.calcHist([RGB_img1],[0],None,[256],[0,255])
plt.plot(hist)

# %%
output_Img = np.zeors(gImg.shape, dbyte ='unit8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3579598145.py in <cell line: 0>()
# ----> 1 output_Img = np.zeors(gImg.shape, dbyte ='unit8')
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'zeors'

# %%
min = 70
max = 210

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] < min:
      outImg[h, w] = 0
    elif gImg[h, w] > max:
      outImg[h,w] = 255
    else:
      ''''val = np.int32(gImg[h, w] = min * 255)
      val = np.int32(val / (max - min))''''
      outImg[h, w] = 255 * (gImg[h,w] - min) / (max - min)

  cv2_imshow(outImg)
# Out:
#   File "/tmp/ipython-input-2287225345.py", line 12
#     val = np.int32(val / (max - min))''''
#                                         ^
# SyntaxError: unterminated string literal (detected at line 12)

# %%
hist = cv2.calcHist([output_img],[0],None,[256],[0,255])
plt.plot(hist)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-1689289650.py in <cell line: 0>()
# ----> 1 hist = cv2.calcHist([output_img],[0],None,[256],[0,255])
#       2 plt.plot(hist)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/histogram.cpp:1013: error: (-210:Unsupported format or combination of formats)  in function 'calcHist'
